# %% [markdown]
# # Inferance on [Breast Ultrasound Images Dataset](https://www.kaggle.com/datasets/aryashah2k/breast-ultrasound-images-dataset) dataset using Fine-tuned SAM.
# 1. Train the model using `train.py` or `train_no_npz.py` and save the checkpoints.

# %%
from glob import glob
import torch
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Prepare the dataset

# %%
from utils.dataset import MedSamDataset

# %%
# dataset directory
dataset_dir = "../Dataset_BUSI_with_GT/benign/"

# !ls $dataset_dir
# Out:
# 'benign (100)_mask_1.png'  'benign (231).png'	      'benign (364).png'
# 'benign (100)_mask.png'    'benign (232)_mask.png'    'benign (365)_mask.png'
# 'benign (100).png'	   'benign (232).png'	      'benign (365).png'
# 'benign (101)_mask.png'    'benign (233)_mask.png'    'benign (366)_mask.png'
# 'benign (101).png'	   'benign (233).png'	      'benign (366).png'
# 'benign (102)_mask.png'    'benign (234)_mask.png'    'benign (367)_mask.png'
# 'benign (102).png'	   'benign (234).png'	      'benign (367).png'
# 'benign (103)_mask.png'    'benign (235)_mask.png'    'benign (368)_mask.png'
# 'benign (103).png'	   'benign (235).png'	      'benign (368).png'
# 'benign (104)_mask.png'    'benign (236)_mask.png'    'benign (369)_mask.png'
# 'benign (104).png'	   'benign (236).png'	      'benign (369).png'
# 'benign (105)_mask.png'    'benign (237)_mask.png'    'benign (36)_mask.png'
# 'benign (105).png'	   'benign (237).png'	      'benign (36).png'
# 'benign (106)_mask.png'    'benign (238)_mask.png'    'benign (370)_mask.png'
# 'benign (106).png'	   'benign (238).png'	      'benign (370).png'
# 'benign (107)_mask.png'    'benign (239)_mask.png'    'benign (371)_mask.png'
# 'benign (107).png'	   'benign (239).png'	      'benign (371).png'
# 'benign (108)_mask.png'    'benign (23)_mask.png'     'benign (372)_mask.png'
# 'benign (108).png'	   'benign (23).png'	      'benign (372).png'
# 'benign (109)_mask.png'    'benign (240)_mask.png'    'benign (373)_mask.png'
# 'benign (109).png'	   'benign (240).png'	      'benign (373).png'
# 'benign (10)_mask.png'	   'benign (241)_mask.png'    'benign (374)_mask.png'
# 'benign (10).png'	   'benign (241).png'	      'benign (374).png'
# 'benign (110)_mask.png'    'benign (242)_mask.png'    'benign (375)_mask.png'
# 'benign (110).png'	   'benign (242).png'	      'benign (375).png'
# 'benign (111)_mask.png'    'benign (243)_mask.png'    'benign (376)_mask.png'
# 'benign (111).png'	   'benign (243).png'	      'benign (376).png'
# 'benign (112)_mask.png'    'benign (244)_mask.png'    'benign (377)_mask.png'
# 'benign (112).png'	   'benign (244).png'	      'benign (377).png'
# 'benign (113)_mask.png'    'benign (245)_mask.png'    'benign (378)_mask.png'
# 'benign (113).png'	   'benign (245).png'	      'benign (378).png'
# 'benign (114)_mask.png'    'benign (246)_mask.png'    'benign (379)_mask.png'
# 'benign (114).png'	   'benign (246).png'	      'benign (379).png'
# 'benign (115)_mask.png'    'benign (247)_mask.png'    'benign (37)_mask.png'
# 'benign (115).png'	   'benign (247).png'	      'benign (37).png'
# 'benign (116)_mask.png'    'benign (248)_mask.png'    'benign (380)_mask.png'
# 'benign (116).png'	   'benign (248).png'	      'benign (380).png'
# 'benign (117)_mask.png'    'benign (249)_mask.png'    'benign (381)_mask.png'
# 'benign (117).png'	   'benign (249).png'	      'benign (381).png'
# 'benign (118)_mask.png'    'benign (24)_mask.png'     'benign (382)_mask.png'
# 'benign (118).png'	   'benign (24).png'	      'benign (382).png'
# 'benign (119)_mask.png'    'benign (250)_mask.png'    'benign (383)_mask.png'
# 'benign (119).png'	   'benign (250).png'	      'benign (383).png'
# 'benign (11)_mask.png'	   'benign (251)_mask.png'    'benign (384)_mask.png'
# 'benign (11).png'	   'benign (251).png'	      'benign (384).png'
# 'benign (120)_mask.png'    'benign (252)_mask.png'    'benign (385)_mask.png'
# 'benign (120).png'	   'benign (252).png'	      'benign (385).png'
# 'benign (121)_mask.png'    'benign (253)_mask.png'    'benign (386)_mask.png'
# 'benign (121).png'	   'benign (253).png'	      'benign (386).png'
# 'benign (122)_mask.png'    'benign (254)_mask.png'    'benign (387)_mask.png'
# 'benign (122).png'	   'benign (254).png'	      'benign (387).png'
# 'benign (123)_mask.png'    'benign (255)_mask.png'    'benign (388)_mask.png'
# 'benign (123).png'	   'benign (255).png'	      'benign (388).png'
# 'benign (124)_mask.png'    'benign (256)_mask.png'    'benign (389)_mask.png'
# 'benign (124).png'	   'benign (256).png'	      'benign (389).png'
# 'benign (125)_mask.png'    'benign (257)_mask.png'    'benign (38)_mask.png'
# 'benign (125).png'	   'benign (257).png'	      'benign (38).png'
# 'benign (126)_mask.png'    'benign (258)_mask.png'    'benign (390)_mask.png'
# 'benign (126).png'	   'benign (258).png'	      'benign (390).png'
# 'benign (127)_mask.png'    'benign (259)_mask.png'    'benign (391)_mask.png'
# 'benign (127).png'	   'benign (259).png'	      'benign (391).png'
# 'benign (128)_mask.png'    'benign (25)_mask_1.png'   'benign (392)_mask.png'
# 'benign (128).png'	   'benign (25)_mask.png'     'benign (392).png'
# 'benign (129)_mask.png'    'benign (25).png'	      'benign (393)_mask.png'
# 'benign (129).png'	   'benign (260)_mask.png'    'benign (393).png'
# 'benign (12)_mask.png'	   'benign (260).png'	      'benign (394)_mask.png'
# 'benign (12).png'	   'benign (261)_mask.png'    'benign (394).png'
# 'benign (130)_mask.png'    'benign (261).png'	      'benign (395)_mask.png'
# 'benign (130).png'	   'benign (262)_mask.png'    'benign (395).png'
# 'benign (131)_mask.png'    'benign (262).png'	      'benign (396)_mask.png'
# 'benign (131).png'	   'benign (263)_mask.png'    'benign (396).png'
# 'benign (132)_mask.png'    'benign (263).png'	      'benign (397)_mask.png'
# 'benign (132).png'	   'benign (264)_mask.png'    'benign (397).png'
# 'benign (133)_mask.png'    'benign (264).png'	      'benign (398)_mask.png'
# 'benign (133).png'	   'benign (265)_mask.png'    'benign (398).png'
# 'benign (134)_mask.png'    'benign (265).png'	      'benign (399)_mask.png'
# 'benign (134).png'	   'benign (266)_mask.png'    'benign (399).png'
# 'benign (135)_mask.png'    'benign (266).png'	      'benign (39)_mask.png'
# 'benign (135).png'	   'benign (267)_mask.png'    'benign (39).png'
# 'benign (136)_mask.png'    'benign (267).png'	      'benign (3)_mask.png'
# 'benign (136).png'	   'benign (268)_mask.png'    'benign (3).png'
# 'benign (137)_mask.png'    'benign (268).png'	      'benign (400)_mask.png'
# 'benign (137).png'	   'benign (269)_mask.png'    'benign (400).png'
# 'benign (138)_mask.png'    'benign (269).png'	      'benign (401)_mask.png'
# 'benign (138).png'	   'benign (26)_mask.png'     'benign (401).png'
# 'benign (139)_mask.png'    'benign (26).png'	      'benign (402)_mask.png'
# 'benign (139).png'	   'benign (270)_mask.png'    'benign (402).png'
# 'benign (13)_mask.png'	   'benign (270).png'	      'benign (403)_mask.png'
# 'benign (13).png'	   'benign (271)_mask.png'    'benign (403).png'
# 'benign (140)_mask.png'    'benign (271).png'	      'benign (404)_mask.png'
# 'benign (140).png'	   'benign (272)_mask.png'    'benign (404).png'
# 'benign (141)_mask.png'    'benign (272).png'	      'benign (405)_mask.png'
# 'benign (141).png'	   'benign (273)_mask.png'    'benign (405).png'
# 'benign (142)_mask.png'    'benign (273).png'	      'benign (406)_mask.png'
# 'benign (142).png'	   'benign (274)_mask.png'    'benign (406).png'
# 'benign (143)_mask.png'    'benign (274).png'	      'benign (407)_mask.png'
# 'benign (143).png'	   'benign (275)_mask.png'    'benign (407).png'
# 'benign (144)_mask.png'    'benign (275).png'	      'benign (408)_mask.png'
# 'benign (144).png'	   'benign (276)_mask.png'    'benign (408).png'
# 'benign (145)_mask.png'    'benign (276).png'	      'benign (409)_mask.png'
# 'benign (145).png'	   'benign (277)_mask.png'    'benign (409).png'
# 'benign (146)_mask.png'    'benign (277).png'	      'benign (40)_mask.png'
# 'benign (146).png'	   'benign (278)_mask.png'    'benign (40).png'
# 'benign (147)_mask.png'    'benign (278).png'	      'benign (410)_mask.png'
# 'benign (147).png'	   'benign (279)_mask.png'    'benign (410).png'
# 'benign (148)_mask.png'    'benign (279).png'	      'benign (411)_mask.png'
# 'benign (148).png'	   'benign (27)_mask.png'     'benign (411).png'
# 'benign (149)_mask.png'    'benign (27).png'	      'benign (412)_mask.png'
# 'benign (149).png'	   'benign (280)_mask.png'    'benign (412).png'
# 'benign (14)_mask.png'	   'benign (280).png'	      'benign (413)_mask.png'
# 'benign (14).png'	   'benign (281)_mask.png'    'benign (413).png'
# 'benign (150)_mask.png'    'benign (281).png'	      'benign (414)_mask.png'
# 'benign (150).png'	   'benign (282)_mask.png'    'benign (414).png'
# 'benign (151)_mask.png'    'benign (282).png'	      'benign (415)_mask.png'
# 'benign (151).png'	   'benign (283)_mask.png'    'benign (415).png'
# 'benign (152)_mask.png'    'benign (283).png'	      'benign (416)_mask.png'
# 'benign (152).png'	   'benign (284)_mask.png'    'benign (416).png'
# 'benign (153)_mask.png'    'benign (284).png'	      'benign (417)_mask.png'
# 'benign (153).png'	   'benign (285)_mask.png'    'benign (417).png'
# 'benign (154)_mask.png'    'benign (285).png'	      'benign (418)_mask.png'
# 'benign (154).png'	   'benign (286)_mask.png'    'benign (418).png'
# 'benign (155)_mask.png'    'benign (286).png'	      'benign (419)_mask.png'
# 'benign (155).png'	   'benign (287)_mask.png'    'benign (419).png'
# 'benign (156)_mask.png'    'benign (287).png'	      'benign (41)_mask.png'
# 'benign (156).png'	   'benign (288)_mask.png'    'benign (41).png'
# 'benign (157)_mask.png'    'benign (288).png'	      'benign (420)_mask.png'
# 'benign (157).png'	   'benign (289)_mask.png'    'benign (420).png'
# 'benign (158)_mask.png'    'benign (289).png'	      'benign (421)_mask.png'
# 'benign (158).png'	   'benign (28)_mask.png'     'benign (421).png'
# 'benign (159)_mask.png'    'benign (28).png'	      'benign (422)_mask.png'
# 'benign (159).png'	   'benign (290)_mask.png'    'benign (422).png'
# 'benign (15)_mask.png'	   'benign (290).png'	      'benign (423)_mask.png'
# 'benign (15).png'	   'benign (291)_mask.png'    'benign (423).png'
# 'benign (160)_mask.png'    'benign (291).png'	      'benign (424)_mask_1.png'
# 'benign (160).png'	   'benign (292)_mask.png'    'benign (424)_mask.png'
# 'benign (161)_mask.png'    'benign (292).png'	      'benign (424).png'
# 'benign (161).png'	   'benign (293)_mask.png'    'benign (425)_mask.png'
# 'benign (162)_mask.png'    'benign (293).png'	      'benign (425).png'
# 'benign (162).png'	   'benign (294)_mask.png'    'benign (426)_mask.png'
# 'benign (163)_mask_1.png'  'benign (294).png'	      'benign (426).png'
# 'benign (163)_mask.png'    'benign (295)_mask.png'    'benign (427)_mask.png'
# 'benign (163).png'	   'benign (295).png'	      'benign (427).png'
# 'benign (164)_mask.png'    'benign (296)_mask.png'    'benign (428)_mask.png'
# 'benign (164).png'	   'benign (296).png'	      'benign (428).png'
# 'benign (165)_mask.png'    'benign (297)_mask.png'    'benign (429)_mask.png'
# 'benign (165).png'	   'benign (297).png'	      'benign (429).png'
# 'benign (166)_mask.png'    'benign (298)_mask.png'    'benign (42)_mask.png'
# 'benign (166).png'	   'benign (298).png'	      'benign (42).png'
# 'benign (167)_mask.png'    'benign (299)_mask.png'    'benign (430)_mask.png'
# 'benign (167).png'	   'benign (299).png'	      'benign (430).png'
# 'benign (168)_mask.png'    'benign (29)_mask.png'     'benign (431)_mask.png'
# 'benign (168).png'	   'benign (29).png'	      'benign (431).png'
# 'benign (169)_mask.png'    'benign (2)_mask.png'      'benign (432)_mask.png'
# 'benign (169).png'	   'benign (2).png'	      'benign (432).png'
# 'benign (16)_mask.png'	   'benign (300)_mask.png'    'benign (433)_mask.png'
# 'benign (16).png'	   'benign (300).png'	      'benign (433).png'
# 'benign (170)_mask.png'    'benign (301)_mask.png'    'benign (434)_mask.png'
# 'benign (170).png'	   'benign (301).png'	      'benign (434).png'
# 'benign (171)_mask.png'    'benign (302)_mask.png'    'benign (435)_mask.png'
# 'benign (171).png'	   'benign (302).png'	      'benign (435).png'
# 'benign (172)_mask.png'    'benign (303)_mask.png'    'benign (436)_mask.png'
# 'benign (172).png'	   'benign (303).png'	      'benign (436).png'
# 'benign (173)_mask_1.png'  'benign (304)_mask.png'    'benign (437)_mask.png'
# 'benign (173)_mask.png'    'benign (304).png'	      'benign (437).png'
# 'benign (173).png'	   'benign (305)_mask.png'    'benign (43)_mask.png'
# 'benign (174)_mask.png'    'benign (305).png'	      'benign (43).png'
# 'benign (174).png'	   'benign (306)_mask.png'    'benign (44)_mask.png'
# 'benign (175)_mask.png'    'benign (306).png'	      'benign (44).png'
# 'benign (175).png'	   'benign (307)_mask.png'    'benign (45)_mask.png'
# 'benign (176)_mask.png'    'benign (307).png'	      'benign (45).png'
# 'benign (176).png'	   'benign (308)_mask.png'    'benign (46)_mask.png'
# 'benign (177)_mask.png'    'benign (308).png'	      'benign (46).png'
# 'benign (177).png'	   'benign (309)_mask.png'    'benign (47)_mask.png'
# 'benign (178)_mask.png'    'benign (309).png'	      'benign (47).png'
# 'benign (178).png'	   'benign (30)_mask.png'     'benign (48)_mask.png'
# 'benign (179)_mask.png'    'benign (30).png'	      'benign (48).png'
# 'benign (179).png'	   'benign (310)_mask.png'    'benign (49)_mask.png'
# 'benign (17)_mask.png'	   'benign (310).png'	      'benign (49).png'
# 'benign (17).png'	   'benign (311)_mask.png'    'benign (4)_mask_1.png'
# 'benign (180)_mask.png'    'benign (311).png'	      'benign (4)_mask.png'
# 'benign (180).png'	   'benign (312)_mask.png'    'benign (4).png'
# 'benign (181)_mask_1.png'  'benign (312).png'	      'benign (50)_mask.png'
# 'benign (181)_mask.png'    'benign (313)_mask.png'    'benign (50).png'
# 'benign (181).png'	   'benign (313).png'	      'benign (51)_mask.png'
# 'benign (182)_mask.png'    'benign (314)_mask.png'    'benign (51).png'
# 'benign (182).png'	   'benign (314).png'	      'benign (52)_mask.png'
# 'benign (183)_mask.png'    'benign (315)_mask_1.png'  'benign (52).png'
# 'benign (183).png'	   'benign (315)_mask.png'    'benign (53)_mask.png'
# 'benign (184)_mask.png'    'benign (315).png'	      'benign (53).png'
# 'benign (184).png'	   'benign (316)_mask.png'    'benign (54)_mask_1.png'
# 'benign (185)_mask.png'    'benign (316).png'	      'benign (54)_mask.png'
# 'benign (185).png'	   'benign (317)_mask.png'    'benign (54).png'
# 'benign (186)_mask.png'    'benign (317).png'	      'benign (55)_mask.png'
# 'benign (186).png'	   'benign (318)_mask.png'    'benign (55).png'
# 'benign (187)_mask.png'    'benign (318).png'	      'benign (56)_mask.png'
# 'benign (187).png'	   'benign (319)_mask.png'    'benign (56).png'
# 'benign (188)_mask.png'    'benign (319).png'	      'benign (57)_mask.png'
# 'benign (188).png'	   'benign (31)_mask.png'     'benign (57).png'
# 'benign (189)_mask.png'    'benign (31).png'	      'benign (58)_mask_1.png'
# 'benign (189).png'	   'benign (320)_mask.png'    'benign (58)_mask.png'
# 'benign (18)_mask.png'	   'benign (320).png'	      'benign (58).png'
# 'benign (18).png'	   'benign (321)_mask.png'    'benign (59)_mask.png'
# 'benign (190)_mask.png'    'benign (321).png'	      'benign (59).png'
# 'benign (190).png'	   'benign (322)_mask.png'    'benign (5)_mask.png'
# 'benign (191)_mask.png'    'benign (322).png'	      'benign (5).png'
# 'benign (191).png'	   'benign (323)_mask.png'    'benign (60)_mask.png'
# 'benign (192)_mask.png'    'benign (323).png'	      'benign (60).png'
# 'benign (192).png'	   'benign (324)_mask.png'    'benign (61)_mask.png'
# 'benign (193)_mask.png'    'benign (324).png'	      'benign (61).png'
# 'benign (193).png'	   'benign (325)_mask.png'    'benign (62)_mask.png'
# 'benign (194)_mask.png'    'benign (325).png'	      'benign (62).png'
# 'benign (194).png'	   'benign (326)_mask.png'    'benign (63)_mask.png'
# 'benign (195)_mask_1.png'  'benign (326).png'	      'benign (63).png'
# 'benign (195)_mask_2.png'  'benign (327)_mask.png'    'benign (64)_mask.png'
# 'benign (195)_mask.png'    'benign (327).png'	      'benign (64).png'
# 'benign (195).png'	   'benign (328)_mask.png'    'benign (65)_mask.png'
# 'benign (196)_mask.png'    'benign (328).png'	      'benign (65).png'
# 'benign (196).png'	   'benign (329)_mask.png'    'benign (66)_mask.png'
# 'benign (197)_mask.png'    'benign (329).png'	      'benign (66).png'
# 'benign (197).png'	   'benign (32)_mask.png'     'benign (67)_mask.png'
# 'benign (198)_mask.png'    'benign (32).png'	      'benign (67).png'
# 'benign (198).png'	   'benign (330)_mask.png'    'benign (68)_mask.png'
# 'benign (199)_mask.png'    'benign (330).png'	      'benign (68).png'
# 'benign (199).png'	   'benign (331)_mask.png'    'benign (69)_mask.png'
# 'benign (19)_mask.png'	   'benign (331).png'	      'benign (69).png'
# 'benign (19).png'	   'benign (332)_mask.png'    'benign (6)_mask.png'
# 'benign (1)_mask.png'	   'benign (332).png'	      'benign (6).png'
# 'benign (1).png'	   'benign (333)_mask.png'    'benign (70)_mask.png'
# 'benign (200)_mask.png'    'benign (333).png'	      'benign (70).png'
# 'benign (200).png'	   'benign (334)_mask.png'    'benign (71)_mask.png'
# 'benign (201)_mask.png'    'benign (334).png'	      'benign (71).png'
# 'benign (201).png'	   'benign (335)_mask.png'    'benign (72)_mask.png'
# 'benign (202)_mask.png'    'benign (335).png'	      'benign (72).png'
# 'benign (202).png'	   'benign (336)_mask.png'    'benign (73)_mask.png'
# 'benign (203)_mask.png'    'benign (336).png'	      'benign (73).png'
# 'benign (203).png'	   'benign (337)_mask.png'    'benign (74)_mask.png'
# 'benign (204)_mask.png'    'benign (337).png'	      'benign (74).png'
# 'benign (204).png'	   'benign (338)_mask.png'    'benign (75)_mask.png'
# 'benign (205)_mask.png'    'benign (338).png'	      'benign (75).png'
# 'benign (205).png'	   'benign (339)_mask.png'    'benign (76)_mask.png'
# 'benign (206)_mask.png'    'benign (339).png'	      'benign (76).png'
# 'benign (206).png'	   'benign (33)_mask.png'     'benign (77)_mask.png'
# 'benign (207)_mask.png'    'benign (33).png'	      'benign (77).png'
# 'benign (207).png'	   'benign (340)_mask.png'    'benign (78)_mask.png'
# 'benign (208)_mask.png'    'benign (340).png'	      'benign (78).png'
# 'benign (208).png'	   'benign (341)_mask.png'    'benign (79)_mask.png'
# 'benign (209)_mask.png'    'benign (341).png'	      'benign (79).png'
# 'benign (209).png'	   'benign (342)_mask.png'    'benign (7)_mask.png'
# 'benign (20)_mask.png'	   'benign (342).png'	      'benign (7).png'
# 'benign (20).png'	   'benign (343)_mask.png'    'benign (80)_mask.png'
# 'benign (210)_mask.png'    'benign (343).png'	      'benign (80).png'
# 'benign (210).png'	   'benign (344)_mask.png'    'benign (81)_mask.png'
# 'benign (211)_mask.png'    'benign (344).png'	      'benign (81).png'
# 'benign (211).png'	   'benign (345)_mask.png'    'benign (82)_mask.png'
# 'benign (212)_mask.png'    'benign (345).png'	      'benign (82).png'
# 'benign (212).png'	   'benign (346)_mask_1.png'  'benign (83)_mask_1.png'
# 'benign (213)_mask.png'    'benign (346)_mask.png'    'benign (83)_mask.png'
# 'benign (213).png'	   'benign (346).png'	      'benign (83).png'
# 'benign (214)_mask.png'    'benign (347)_mask.png'    'benign (84)_mask.png'
# 'benign (214).png'	   'benign (347).png'	      'benign (84).png'
# 'benign (215)_mask.png'    'benign (348)_mask.png'    'benign (85)_mask.png'
# 'benign (215).png'	   'benign (348).png'	      'benign (85).png'
# 'benign (216)_mask.png'    'benign (349)_mask.png'    'benign (86)_mask.png'
# 'benign (216).png'	   'benign (349).png'	      'benign (86).png'
# 'benign (217)_mask.png'    'benign (34)_mask.png'     'benign (87)_mask.png'
# 'benign (217).png'	   'benign (34).png'	      'benign (87).png'
# 'benign (218)_mask.png'    'benign (350)_mask.png'    'benign (88)_mask.png'
# 'benign (218).png'	   'benign (350).png'	      'benign (88).png'
# 'benign (219)_mask.png'    'benign (351)_mask.png'    'benign (89)_mask.png'
# 'benign (219).png'	   'benign (351).png'	      'benign (89).png'
# 'benign (21)_mask.png'	   'benign (352)_mask.png'    'benign (8)_mask.png'
# 'benign (21).png'	   'benign (352).png'	      'benign (8).png'
# 'benign (220)_mask.png'    'benign (353)_mask.png'    'benign (90)_mask.png'
# 'benign (220).png'	   'benign (353).png'	      'benign (90).png'
# 'benign (221)_mask.png'    'benign (354)_mask.png'    'benign (91)_mask.png'
# 'benign (221).png'	   'benign (354).png'	      'benign (91).png'
# 'benign (222)_mask.png'    'benign (355)_mask.png'    'benign (92)_mask_1.png'
# 'benign (222).png'	   'benign (355).png'	      'benign (92)_mask.png'
# 'benign (223)_mask.png'    'benign (356)_mask.png'    'benign (92).png'
# 'benign (223).png'	   'benign (356).png'	      'benign (93)_mask_1.png'
# 'benign (224)_mask.png'    'benign (357)_mask.png'    'benign (93)_mask.png'
# 'benign (224).png'	   'benign (357).png'	      'benign (93).png'
# 'benign (225)_mask.png'    'benign (358)_mask.png'    'benign (94)_mask.png'
# 'benign (225).png'	   'benign (358).png'	      'benign (94).png'
# 'benign (226)_mask.png'    'benign (359)_mask.png'    'benign (95)_mask.png'
# 'benign (226).png'	   'benign (359).png'	      'benign (95).png'
# 'benign (227)_mask.png'    'benign (35)_mask.png'     'benign (96)_mask.png'
# 'benign (227).png'	   'benign (35).png'	      'benign (96).png'
# 'benign (228)_mask.png'    'benign (360)_mask.png'    'benign (97)_mask.png'
# 'benign (228).png'	   'benign (360).png'	      'benign (97).png'
# 'benign (229)_mask.png'    'benign (361)_mask.png'    'benign (98)_mask_1.png'
# 'benign (229).png'	   'benign (361).png'	      'benign (98)_mask.png'
# 'benign (22)_mask.png'	   'benign (362)_mask.png'    'benign (98).png'
# 'benign (22).png'	   'benign (362).png'	      'benign (99)_mask.png'
# 'benign (230)_mask.png'    'benign (363)_mask.png'    'benign (99).png'
# 'benign (230).png'	   'benign (363).png'	      'benign (9)_mask.png'
# 'benign (231)_mask.png'    'benign (364)_mask.png'    'benign (9).png'

# %% [markdown]
# Prepare the `dataframe` with columns for the `images` and `masks`

# %%
import re

all_images = glob(dataset_dir+"/*png")

mask_pattern = re.compile(r'(.*)mask.png')
image_pattern = re.compile(r'(.*)\).png')

images = sorted([image for image in all_images if image_pattern.match(image)])
masks = sorted([mask for mask in all_images if mask_pattern.match(mask)])

df = pd.DataFrame(
    {
    "image":images,
    "mask":masks
    }
    )
df.head()
# Out:
#                                              image  \
# 0    ../Dataset_BUSI_with_GT/benign/benign (1).png
# 1   ../Dataset_BUSI_with_GT/benign/benign (10).png
# 2  ../Dataset_BUSI_with_GT/benign/benign (100).png
# 3  ../Dataset_BUSI_with_GT/benign/benign (101).png
# 4  ../Dataset_BUSI_with_GT/benign/benign (102).png
#
#                                                 mask
# 0  ../Dataset_BUSI_with_GT/benign/benign (1)_mask...
# 1  ../Dataset_BUSI_with_GT/benign/benign (10)_mas...
# 2  ../Dataset_BUSI_with_GT/benign/benign (100)_ma...
# 3  ../Dataset_BUSI_with_GT/benign/benign (101)_ma...
# 4  ../Dataset_BUSI_with_GT/benign/benign (102)_ma...

# %% [markdown]
# Prepare the pytorch `Dataset` object

# %%
# `image_dir` and `mask_dir` will be omitted since the column hold the relative
# path of the images and masks
ds = MedSamDataset(df,image_col="image",mask_col="mask")

# %% [markdown]
# Prepare the pytorch `DataLoader` object

# %%
from torch.utils.data import DataLoader

batch_size = 4

dataloader = DataLoader(ds,batch_size=batch_size,shuffle=True)

# %% [markdown]
# display sample image and mask pairs in a given batch

# %%
images,masks,bboxes = next(iter(dataloader))

images.shape, masks.shape, bboxes.shape,
# Out:
# (torch.Size([4, 3, 256, 256]),
#  torch.Size([4, 1, 256, 256]),
#  torch.Size([4, 4]))

# %%
for i in range(images.shape[0]):
  image = images[i]
  mask = masks[i]
  bbox = bboxes[i]

  plt.figure(figsize=(10,10))
  plt.subplot(1,2,1)
  rect = patches.Rectangle((bbox[0], bbox[1]), bbox[2] - bbox[0],bbox[3] - bbox[1], linewidth=1, edgecolor='r', facecolor='none')
  plt.imshow(np.uint8(image.permute(1,2,0).numpy()),cmap="gray")
  plt.gca().add_patch(rect)

  plt.subplot(1,2,2)
  plt.imshow(mask.permute(1,2,0),cmap="gray")

  plt.show()

# %% [markdown]
# ### Inferance and Evaluation on finetuned SAM

# %%
import torch
from torch.utils.data import DataLoader
from segment_anything import sam_model_registry,SamPredictor
from segment_anything.utils.transforms import ResizeLongestSide

# %% [markdown]
# Load checkpoints

# %%
sam_checkpoint_dir = '../SAM_weights/sam_vit_b_01ec64.pth'
med_sam_checkpoint_dir = "./finetune_weights/medsam_finetune_2023-05-16-09-55.pth"
model_type = 'vit_b'
device = 'cuda:0'

# %%
# initialize sam model
sam_model = sam_model_registry[model_type](checkpoint=med_sam_checkpoint_dir).to(device)

# %%
def dice_coefficient(preds, targets):
  smooth = 1.0
  assert preds.size() == targets.size()

  iflat = preds.contiguous().view(-1)
  tflat = targets.contiguous().view(-1)
  intersection = (iflat * tflat).sum()
  dice = (2.0 * intersection + smooth) / (iflat.sum() + tflat.sum() + smooth)
  return dice

# %%
@torch.inference_mode()
def medsam_prediction(image,bbox):
    sam_trans = ResizeLongestSide(sam_model.image_encoder.img_size)
    #trans_image = image.unsqueeze(0).to(device)
    trans_image = sam_trans.apply_image_torch(image)
    box = sam_trans.apply_boxes(bbox, (256, 256))
    box_tensor = torch.as_tensor(box, dtype=torch.float, device=device)
    # Get predictioin mask
    
    image_embeddings = sam_model.image_encoder(trans_image)  # (B,256,64,64)

    sparse_embeddings, dense_embeddings = sam_model.prompt_encoder(
        points=None,
        boxes=box_tensor,
        masks=None,
    )
    mask_predictions, _ = sam_model.mask_decoder(
        image_embeddings=image_embeddings.to(device),  # (B, 256, 64, 64)
        image_pe=sam_model.prompt_encoder.get_dense_pe(),  # (1, 256, 64, 64)
        sparse_prompt_embeddings=sparse_embeddings,  # (B, 2, 256)
        dense_prompt_embeddings=dense_embeddings,  # (B, 256, 64, 64)
        multimask_output=False,
    )
    mask_predictions = torch.sigmoid(mask_predictions)

    return (mask_predictions > 0.5).int()

# %%
def show_mask(mask, ax, random_color=False):
    if random_color:
        color = np.concatenate([np.random.random(3), np.array([0.6])], axis=0)
    else:
        color = np.array([251/255, 252/255, 30/255, 0.5])
    h, w = mask.shape[-2:]
    mask_image = mask.reshape(h, w, 1) * color.reshape(1, 1, -1)
    ax.imshow(mask_image)

# %%
def show_box(box, ax):
    x0, y0 = box[0], box[1]
    w, h = box[2] - box[0], box[3] - box[1]
    ax.add_patch(plt.Rectangle((x0, y0), w, h, edgecolor='blue', facecolor=(0,0,0,0), lw=2))

# %%
images = images.to(device)
masks = masks.to(device)
mask_prediction = medsam_prediction(images,bboxes)


fig,axs = plt.subplots(images.shape[0],3,figsize=(10,10),subplot_kw={"xticks":[],"yticks":[]})
for i in range(images.shape[0]):

  image = np.uint8(images[i].permute(1,2,0).cpu().numpy())
  mask = masks[i]
  pred_mask = mask_prediction[i]

  dice = dice_coefficient(pred_mask,mask)

  mask = mask.cpu().numpy()
  pred_mask = pred_mask.cpu().numpy()

  axs[i][0].imshow(image,cmap="gray")

  axs[i][1].imshow(image,cmap="gray")
  show_mask(mask,axs[i][1])
  show_box(bboxes[i],axs[i][1])
  axs[i][1].set_title(f"GT")

  axs[i][2].imshow(image,cmap="gray")
  show_mask(pred_mask,axs[i][2])
  show_box(bboxes[i],axs[i][2])
  
  axs[i][2].set_title(f"Dice = {dice.item():.2f}")

  plt.tight_layout()
